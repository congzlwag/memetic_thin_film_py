# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import sys
sys.path.append('algorithm/')

# %%
from DispData import DispData
from refl_disp import refl_disp_norm

# %%
wl_sample_fine = np.array([2.5, 22, 500])

# %%
cd algorithms/
# Out:
# /Users/congzlwag/Git/EE236A/SlabStack/algorithms

# %%
dipode = DispData(["HfO2","MgF2","SiC","Ag"], wl_sample_fine, wl_sample_fine)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ba981e43f6bd> in <module>
# ----> 1 dipode = DispData(["HfO2","MgF2","SiC","Ag"], wl_sample_fine, wl_sample_fine)
#
# ~/Git/EE236A/memetic_thin_film_py/algorithm/DispData.py in __init__(self, material_key, wvlen_sample, wvlen_fine)
#      54
#      55         #%% Generate the dispersion for each material
# ---> 56         self.ref_ind, self.ref_ind_fine = self.disp_generate(material_key, self.wvlen_vec, self.wvlen_vec_fine)
#      57
#      58
#
# ~/Git/EE236A/memetic_thin_film_py/algorithm/DispData.py in disp_generate(self, material_key, wvlen_vec, wvlen_vec_fine)
#     166
#     167             try:
# --> 168                 A = array(pd.read_excel(file_name))
#     169             except NameError:
#     170                 print('The material database does not contain', material_key[i])
#
# ...

# %%
Yudisp = {}
for mat, dat in zip(["HfO2","MgF2","SiC","Ag"], dipode.ref_ind_fine.T):
    Yudisp[mat] = dat

# %%
dipode.disp_plot('Ag')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dipode.wvlen_vec_fine, mydisp['Ag'].real)
plt.plot(dipode.wvlen_vec_fine, mydisp['Ag'].imag,'--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
thicknesses = np.array([3.279, 0.640, 0.657, 1.940, 1.337, 0.047])
n_middle = np.array([Yudisp['MgF2'], Yudisp['HfO2'], Yudisp['SiC'], Yudisp['MgF2'], Yudisp["SiC"], Yudisp['MgF2']]).T

# %%
R_norm = refl_disp_norm(n_in=1, n_disp=n_middle, n_out=Yudisp['Ag'], d=thicknesses, wvlen=dipode.wvlen_vec_fine)

# %%
plt.plot(dipode.wvlen_vec_fine, 1- R_norm)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
E_ = np.arange(1e-3, 1, 1e-3)

# %%
plt.plot(E_, 1/(-1 + 2 * np.log(E_)))
# Out:
# <img src="data:image/png;base64,..." width="640">
